# %%
import os
import torch
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import deque

import matplotlib.pyplot as plt

from env import PursuitEvasionEnv
from models import GCN_QNetwork
from torch_geometric.utils import dense_to_sparse
import numpy as np

# %%
class ReplayBuffer:
    def __init__(self, capacity=100000):
        self.buffer = deque(maxlen=capacity)

    def push(self, id, state, actions, reward, next_state, done):
        self.buffer.append((id, state, actions, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        return zip(*batch)

    def __len__(self):
        return len(self.buffer)

# %%
def obs_to_tensors(obs, pid, device):
    """
    obs[pid] contains:
      - 'features': np.array shape (N, F)
      - 'adj':      np.array shape (N, N)
    Returns (x, edge_index) or (None, None) if no nodes.
    """
    info = obs.get(pid, None)
    if info is None: return None, None

    feats = info["features"]
    if feats.shape[0] == 0:
        return None, None

    adj = info["adj"]
    # to torch
    x = torch.tensor(feats, dtype=torch.float32, device=device)
    edge_index, _ = dense_to_sparse(torch.tensor(adj, dtype=torch.float32, device=device))
    return x, edge_index

# %%
def calc_evader_speed(e, total_eps=400, min_speed=0.35, max_speed=1.0):
    # ramp parameters
    ramp_eps = total_eps - 100       # 300 if total=400
    a = 2                             # power >1 => fast start, slow end

    if e >= ramp_eps:
        return max_speed
    t = e / ramp_eps                  # normalized [0,1)
    return min_speed + (max_speed-min_speed)*(1 - (1 - t)**a)

# %%
def train_shared_policy(
    num_episodes=200,
    batch_size=16,
    gamma=0.99,
    lr=1e-3,
    save_dir='checkpoints',
    save_interval=50,
    plot_interval=10
):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    os.makedirs(save_dir, exist_ok=True)

    env = PursuitEvasionEnv(random_start=True, evader_strat="potential_fields")
    evader_speed = 0.1
    feature_dim = env._get_observation()[0]["features"].shape[1]

    policy_net = GCN_QNetwork(in_features=feature_dim, hidden_dim=64).to(device)
    target_net = GCN_QNetwork(in_features=feature_dim, hidden_dim=64).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=lr)
    replay_buffer = ReplayBuffer()

    epsilon, eps_end, eps_decay = 1.0, 0.1, 0.99995

    rewards_history = []

    for ep in range(1, num_episodes+1):
        successful_pursuers = 0
        obs = env.reset(random_start=True, evader_strat="potential_fields")
        done = False
        episode_reward = 0

        print('##################################################')
        print(f'Evader Start Pos: {env.evader.x}, {env.evader.y}')

        while not done:
            actions = {}
            for p in env.pursuers:
                if not p.is_moving:
                    x, edge_index = obs_to_tensors(obs, p.id, device)
                    if x is None:
                        actions[p.id] = 0
                    elif random.random() < epsilon:
                        actions[p.id] = random.randrange(x.size(0))
                    else:
                        with torch.no_grad():
                            q_vals = policy_net(x, edge_index)
                            actions[p.id] = int(q_vals.argmax().item())

            obs, transitions, done = env.step(actions, evader_speed=evader_speed)
            if done:
                for p in env.pursuers:
                    if p.found_evader:
                        successful_pursuers += 1

            if env.step_count % 200 == 0:
                print(f'Episode {ep} step count: {env.step_count}, evader pos: {env.evader.x}, {env.evader.y}')

            for id, prev_obs, prev_action, reward, p_done in transitions:
                replay_buffer.push(id, prev_obs, prev_action, reward, obs[id], p_done)
                episode_reward += reward


            # --- DQN update ---
            if len(replay_buffer) >= batch_size:
                ids, states, acts, rewards, next_states, dones = replay_buffer.sample(batch_size)
                losses = []
                for pid, s, action_idx, r, ns, d in zip(ids, states, acts, rewards, next_states, dones):
                    x_s, ei_s = obs_to_tensors(s, pid, device)
                    if x_s is None or action_idx >= x_s.size(0): continue
                    Q_s = policy_net(x_s, ei_s)[action_idx]

                    x_ns, ei_ns = obs_to_tensors(ns, pid, device)
                    with torch.no_grad():
                        Q_ns = target_net(x_ns, ei_ns).max().item() if x_ns is not None else 0.0
                    target = r + gamma * (1 - float(d)) * Q_ns
                    target_t = torch.tensor(target, dtype=torch.float32, device=device)
                    losses.append(F.mse_loss(Q_s, target_t))

                if losses:
                    optimizer.zero_grad()
                    torch.stack(losses).mean().backward()
                    optimizer.step()

            epsilon = max(eps_end, epsilon * eps_decay)

        # --- End of episode bookkeeping ---
        rewards_history.append(episode_reward)

        # Increase Evader Speed
        evader_speed = calc_evader_speed(ep)

        # Sync target
        if ep % 10 == 0:
            target_net.load_state_dict(policy_net.state_dict())

        # Save model
        if ep % save_interval == 0:
            torch.save(policy_net.state_dict(), os.path.join(save_dir, f'policy_ep{ep}.pt'))

        # Plot rewards
        if ep % plot_interval == 0:
            plt.figure()
            # Actual rewards (transparent)
            plt.plot(
                rewards_history,
                label='Episode Reward',
                alpha=0.3
            )
            # Moving average
            if len(rewards_history) >= plot_interval:
                window = plot_interval
                mov_avg = np.convolve(
                    rewards_history,
                    np.ones(window) / window,
                    mode='valid'
                )
                plt.plot(
                    np.arange(window-1, len(rewards_history)),
                    mov_avg,
                    label=f'{window}-Ep Moving Avg',
                    color='blue'
                )
            plt.xlabel('Episode')
            plt.ylabel('Reward')
            plt.title('Training Reward Curve')
            plt.legend()
            plt.grid(True)
            plt.tight_layout()
            plt.savefig(os.path.join(save_dir, 'reward_curve.png'))
            plt.close()

        print(f"Length of Buffer: {len(replay_buffer)}")
        print(f"Episode {ep}/{num_episodes}  Reward: {episode_reward:.2f}  Epsilon: {epsilon:.3f}   | Successful Pursuers: {successful_pursuers}   Evader Speed: {evader_speed}")
        print(f"P1 Area Seen: {env.pursuers[0].prev_area_seen}  P2 Area Seen: {env.pursuers[1].prev_area_seen}  P3 Area Seen: {env.pursuers[2].prev_area_seen}")

    # --- Final save & plot ---
    torch.save(policy_net.state_dict(), os.path.join(save_dir, 'policy_final.pt'))
    plt.figure()
    plt.plot(rewards_history, label='Episode Reward', alpha=0.3)
    if len(rewards_history) >= plot_interval:
        window = plot_interval
        mov_avg = np.convolve(
            rewards_history,
            np.ones(window) / window,
            mode='valid'
        )
        plt.plot(
            np.arange(window-1, len(rewards_history)),
            mov_avg,
            label=f'{window}-Ep Moving Avg',
            color='blue'
        )
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Reward Curve (Final)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, 'reward_curve_final.png'))
    plt.close()

    print("Training complete!")

# %%
train_shared_policy(
    num_episodes=400,
    batch_size=16,
    gamma=0.99,
    lr=1e-4,
    save_dir='checkpoints',
    save_interval=50,
    plot_interval=10
)
# Out:
# ##################################################
# Evader Start Pos: 56, 34
# Episode 1 step count: 200, evader pos: 53, 18
# Episode 1 step count: 400, evader pos: 56, 3
# Length of Buffer: 65
# Episode 1/400  Reward: 163.97  Epsilon: 0.971   | Successful Pursuers: 3   Evader Speed: 0.35432611111111106
# P1 Area Seen: 667  P2 Area Seen: 1843  P3 Area Seen: 759
# ##################################################
# Evader Start Pos: 57, 48
# Episode 2 step count: 200, evader pos: 59, 48
# Episode 2 step count: 400, evader pos: 59, 48
# Episode 2 step count: 600, evader pos: 59, 48
# Episode 2 step count: 800, evader pos: 59, 48
# Episode 2 step count: 1000, evader pos: 59, 48
# Episode 2 step count: 1200, evader pos: 59, 48
# Episode 2 step count: 1400, evader pos: 59, 48
# Episode 2 step count: 1600, evader pos: 59, 48
# Length of Buffer: 165
# Episode 2/400  Reward: 95.20  Epsilon: 0.896   | Successful Pursuers: 1   Evader Speed: 0.35863777777777783
# P1 Area Seen: 766  P2 Area Seen: 3477  P3 Area Seen: 3249
# ##################################################
# Evader Start Pos: 37, 18
# Episode 3 step count: 200, evader pos: 19, 1
# Episode 3 step count: 400, evader pos: 19, 1
# Episode 3 step count: 600, evader pos: 19, 1
# Episode 3 step count: 800, evader pos: 19, 1
# Episode 3 step count: 1000, evader pos: 19, 1
# Episode 3 step count: 1200, evader pos: 19, 1
# Episode 3 step count: 1400, evader pos: 19, 1
# Episode 3 step count: 1600, evader pos: 19, 1
# Length of Buffer: 304
# Episode 3/400  Reward: 46.91  Epsilon: 0.827   | Successful Pursuers: 1   Evader Speed: 0.362935
# P1 Area Seen: 3363  P2 Area Seen: 632  P3 Area Seen: 2938
# ##################################################
# Evader Start Pos: 46, 24
# Episode 4 step count: 200, evader pos: 22, 27
# Episode 4 step count: 400, evader pos: 22, 27
# Episode 4 step count: 600, evader pos: 22, 27
# Episode 4 step count: 800, evader pos: 22, 27
# Episode 4 step count: 1000, evader pos: 22, 27
# Episode 4 step count: 1200, evader pos: 22, 27
# Episode 4 step count: 1400, evader pos: 22, 27
# Episode 4 step count: 1600, evader pos: 22, 27
# Length of Buffer: 403
# Episode 4/400  Reward: 92.00  Epsilon: 0.764   | Successful Pursuers: 2   Evader Speed: 0.3672177777777777
# P1 Area Seen: 1409  P2 Area Seen: 880  P3 Area Seen: 1809
# ##################################################
# Evader Start Pos: 54, 7
# Episode 5 step count: 200, evader pos: 58, 8
# Episode 5 step count: 400, evader pos: 59, 1
# Episode 5 step count: 600, evader pos: 59, 1
# Episode 5 step count: 800, evader pos: 59, 1
# Episode 5 step count: 1000, evader pos: 59, 1
# Length of Buffer: 501
# Episode 5/400  Reward: 98.18  Epsilon: 0.722   | Successful Pursuers: 3   Evader Speed: 0.37148611111111113
# P1 Area Seen: 749  P2 Area Seen: 1000  P3 Area Seen: 978
# ##################################################
# Evader Start Pos: 54, 7
# Episode 6 step count: 200, evader pos: 8, 13
# Episode 6 step count: 400, evader pos: 4, 49
# Episode 15 step count: 1600, evader pos: 19, 27
# Length of Buffer: 1902
# Episode 15/400  Reward: -186.75  Epsilon: 0.326   | Successful Pursuers: 1   Evader Speed: 0.413375
# P1 Area Seen: 2623  P2 Area Seen: 706  P3 Area Seen: 1182
# ##################################################
# Evader Start Pos: 57, 48
# Episode 16 step count: 200, evader pos: 32, 27
# Episode 16 step count: 400, evader pos: 32, 27
# Episode 16 step count: 600, evader pos: 22, 27
# Episode 16 step count: 800, evader pos: 22, 27
# Episode 16 step count: 1000, evader pos: 22, 27
# Episode 16 step count: 1200, evader pos: 22, 27
# Episode 16 step count: 1400, evader pos: 22, 27
# Episode 16 step count: 1600, evader pos: 22, 27
# Length of Buffer: 2104
# Episode 16/400  Reward: 2.04  Epsilon: 0.301   | Successful Pursuers: 2   Evader Speed: 0.41748444444444444
# P1 Area Seen: 2673  P2 Area Seen: 875  P3 Area Seen: 2370
# ##################################################
# Evader Start Pos: 56, 34
# Length of Buffer: 2170
# Episode 17/400  Reward: 45.62  Epsilon: 0.298   | Successful Pursuers: 1   Evader Speed: 0.42157944444444445
# P1 Area Seen: 845  P2 Area Seen: 755  P3 Area Seen: 655
# ##################################################
# Evader Start Pos: 59, 12
# Episode 18 step count: 200, evader pos: 11, 48
# Length of Buffer: 2247
# Episode 18/400  Reward: 31.41  Epsilon: 0.295   | Successful Pursuers: 1   Evader Speed: 0.42566000000000004
# P1 Area Seen: 1061  P2 Area Seen: 766  P3 Area Seen: 658
# ##################################################
# Evader Start Pos: 54, 7
# Episode 19 step count: 200, evader pos: 21, 1
# Episode 19 step count: 400, evader pos: 21, 1
# Episode 19 step count: 600, evader pos: 21, 1
# Length of Buffer: 2325
# Episode 19/400  Reward: 171.47  Epsilon: 0.284   | Successful Pursuers: 3   Evader Speed: 0.42972611111111114
# P1 Area Seen: 648  P2 Area Seen: 990  P3 Area Seen: 2598
# ##################################################
# Evader Start Pos: 68, 48
# Episode 20 step count: 200, evader pos: 11, 26
# Length of Buffer: 2401
# Episode 20/400  Reward: -10.15  Epsilon: 0.280   | Successful Pursuers: 0   Evader Speed: 0.4337777777777777
# P1 Area Seen: 808  P2 Area Seen: 1038  P3 Area Seen: 889
# ##################################################
# Evader Start Pos: 28, 1
# Episode 21 step count: 200, evader pos: 32, 1
# Episode 21 step count: 400, evader pos: 32, 1
# Episode 21 step count: 600, evader pos: 32, 1
# Episode 21 step count: 800, evader pos: 32, 1
# Episode 21 step count: 1000, evader pos: 21, 1
# Length of Buffer: 2526
# Episode 21/400  Reward: 160.81  Epsilon: 0.266   | Successful Pursuers: 3   Evader Speed: 0.43781500000000007
# P1 Area Seen: 2719  P2 Area Seen: 862  P3 Area Seen: 2836
# ##################################################
# Evader Start Pos: 68, 48
# Episode 22 step count: 200, evader pos: 59, 1
# Episode 22 step count: 400, evader pos: 59, 1
# Episode 22 step count: 600, evader pos: 59, 1
# Episode 22 step count: 800, evader pos: 59, 1
# Episode 22 step count: 1000, evader pos: 59, 1
Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.7053044444444445
# P1 Area Seen: 3195  P2 Area Seen: 500  P3 Area Seen: 3457
# ##################################################
# Evader Start Pos: 61, 42
# Episode 99 step count: 200, evader pos: 59, 1
# Episode 99 step count: 400, evader pos: 59, 1
# Episode 99 step count: 600, evader pos: 59, 1
# Episode 99 step count: 800, evader pos: 59, 1
# Length of Buffer: 10607
# Episode 99/400  Reward: 183.56  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.708215
# P1 Area Seen: 663  P2 Area Seen: 2681  P3 Area Seen: 1980
# ##################################################
# Evader Start Pos: 75, 46
# Length of Buffer: 10644
# Episode 100/400  Reward: 165.85  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.711111111111111
# P1 Area Seen: 1035  P2 Area Seen: 713  P3 Area Seen: 798
# ##################################################
# Evader Start Pos: 75, 33
# Episode 101 step count: 200, evader pos: 21, 1
# Episode 101 step count: 400, evader pos: 21, 1
# Episode 101 step count: 600, evader pos: 32, 1
# Episode 101 step count: 800, evader pos: 32, 1
# Episode 101 step count: 1000, evader pos: 32, 1
# Episode 101 step count: 1200, evader pos: 32, 1
# Episode 101 step count: 1400, evader pos: 32, 1
# Episode 101 step count: 1600, evader pos: 32, 1
# Length of Buffer: 10749
# Episode 101/400  Reward: 76.36  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 0.7139927777777777
# P1 Area Seen: 716  P2 Area Seen: 3568  P3 Area Seen: 3555
# ##################################################
# Evader Start Pos: 37, 18
# Episode 102 step count: 200, evader pos: 22, 27
# Length of Buffer: 10786
# Episode 102/400  Reward: 179.19  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.71686
# P1 Area Seen: 1223  P2 Area Seen: 582  P3 Area Seen: 1628
# ##################################################
# Evader Start Pos: 50, 18
# Length of Buffer: 10808
# Episode 103/400  Reward: 19.40  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 0.7197127777777776
# P1 Area Seen: 760  P2 Area Seen: 752  P3 Area Seen: 661
# ##################################################
# Evader Start Pos: 57, 48
# Episode 104 step count: 200, evader pos: 21, 1
# Episode 104 step count: 400, evader pos: 21, 1
# Length of Buffer: 10885
# Episode 104/400  Reward: 167.80  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.7225511111111111
# P1 Area Seen: 623  P2 Area Seen: 1673  P3 Area Seen: 2148
# ##################################################
# Evader Start Pos: 61, 42
# Episode 105 step count: 200, evader pos: 32, 1
# Episode 105 step count: 400, evader pos: 21, 1
# Length of Buffer: 10948
# Episode 105/400  Reward: 175.55  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 0.7253749999999999
# P1 Area Seen: 1269  P2 Area Seen: 807  P3 Area Seen: 2404
# ##################################################
# Evader Start Pos: 68, 48
# Episode 106 step count: 200, evader pos: 59, 1
# Episode 106 step count: 400, evader pos: 59, 1
# Episode 106 step count: 600, evader pos: 59, 1
# Length of Buffer: 11000
# ...
# Episode 353 step count: 400, evader pos: 32, 1
# Episode 353 step count: 600, evader pos: 32, 1
# Episode 353 step count: 800, evader pos: 21, 1
# Episode 353 step count: 1000, evader pos: 21, 1
# Episode 353 step count: 1200, evader pos: 21, 1
# Episode 353 step count: 1400, evader pos: 21, 1
# Episode 353 step count: 1600, evader pos: 21, 1
# Length of Buffer: 22396
# Episode 353/400  Reward: 140.87  Epsilon: 0.100   | Successful Pursuers: 2   Evader Speed: 1.0
# P1 Area Seen: 2480  P2 Area Seen: 661  P3 Area Seen: 3717
# ##################################################
# Evader Start Pos: 75, 33
# Length of Buffer: 22418
# Episode 354/400  Reward: 19.96  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed:
P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 61, 42
# Length of Buffer: 23366
# Episode 378/400  Reward: 9.74  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 1019  P2 Area Seen: 474  P3 Area Seen: 673
# ##################################################
# Evader Start Pos: 56, 27
# Length of Buffer: 23391
# Episode 379/400  Reward: 11.95  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 553  P2 Area Seen: 773  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 75, 46
# Episode 380 step count: 200, evader pos: 21, 1
# Episode 380 step count: 400, evader pos: 21, 1
# Episode 380 step count: 600, evader pos: 21, 1
# Episode 380 step count: 800, evader pos: 21, 1
# Episode 380 step count: 1000, evader pos: 21, 1
# Episode 380 step count: 1200, evader pos: 21, 1
# Episode 380 step count: 1400, evader pos: 21, 1
# Episode 380 step count: 1600, evader pos: 21, 1
# Length of Buffer: 23454
# Episode 380/400  Reward: 141.60  Epsilon: 0.100   | Successful Pursuers: 2   Evader Speed: 1.0
# P1 Area Seen: 760  P2 Area Seen: 1806  P3 Area Seen: 3347
# ##################################################
# Evader Start Pos: 59, 12
# Episode 381 step count: 200, evader pos: 32, 1
# Episode 381 step count: 400, evader pos: 21, 1
# Length of Buffer: 23490
# Episode 381/400  Reward: 192.59  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 1269  P2 Area Seen: 675  P3 Area Seen: 2385
# ##################################################
# Evader Start Pos: 46, 24
# Length of Buffer: 23512
# Episode 382/400  Reward: 71.86  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 1251  P2 Area Seen: 545  P3 Area Seen: 661
# ##################################################
# Evader Start Pos: 28, 1
# Length of Buffer: 23528
# Episode 383/400  Reward: 66.13  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 555  P2 Area Seen: 582  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 68, 48
# Episode 384 step count: 200, evader pos: 1, 1
# Episode 384 step count: 400, evader pos: 1, 1
# Episode 384 step count: 600, evader pos: 1, 1
# Length of Buffer: 23569
# Episode 384/400  Reward: 193.64  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 623  P2 Area Seen: 893  P3 Area Seen: 3012
# ##################################################
# Evader Start Pos: 54, 7
# Length of Buffer: 23590
# Episode 385/400  Reward: 64.51  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 760  P2 Area Seen: 574  P3 Area Seen: 526
# ##################################################
# Evader Start Pos: 34, 10
# Length of Buffer: 23608
# Episode 386/400  Reward: 17.40  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 724  P2 Area Seen: 702  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 34, 10
# Episode 387 step count: 200, evader pos: 22, 27
# Length of Buffer: 23637
# Episode 387/400  Reward: 182.85  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 1172  P2 Area Seen: 563  P3 Area Seen: 1783
# ##################################################
# Evader Start Pos: 59, 12
# Length of Buffer: 23662
# Episode 388/400  Reward: 63.73  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 760  P2 Area Seen: 608  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 28, 1
# Length of Buffer: 23687
# Episode 389/400  Reward: 56.08  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 705  P2 Area Seen: 518  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 61, 42
# Episode 390 step count: 200, evader pos: 19, 27
# Episode 390 step count: 400, evader pos: 19, 27
# Episode 390 step count: 600, evader pos: 19, 27
# Episode 390 step count: 800, evader pos: 19, 27
# Episode 390 step count: 1000, evader pos: 16, 42
# Length of Buffer: 23733
# Episode 390/400  Reward: 90.09  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 2184  P2 Area Seen: 659  P3 Area Seen: 2648
# ##################################################
# Evader Start Pos: 61, 42
# Episode 391 step count: 200, evader pos: 32, 27
# Length of Buffer: 23770
# Episode 391/400  Reward: 172.47  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 603  P2 Area Seen: 589  P3 Area Seen: 2115
# ##################################################
# Evader Start Pos: 68, 48
# Episode 392 step count: 200, evader pos: 22, 27
# Episode 392 step count: 400, evader pos: 22, 27
# Episode 392 step count: 600, evader pos: 22, 27
# Length of Buffer: 23826
# Episode 392/400  Reward: 187.90  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 2346  P2 Area Seen: 753  P3 Area Seen: 2266
# ##################################################
# Evader Start Pos: 46, 24
# Length of Buffer: 23848
# Episode 393/400  Reward: 8.91  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 535  P2 Area Seen: 474  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 28, 1
# Episode 394 step count: 200, evader pos: 19, 27
# Episode 394 step count: 400, evader pos: 19, 27
# Length of Buffer: 23891
# Episode 394/400  Reward: 85.87  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 1964  P2 Area Seen: 529  P3 Area Seen: 1936
# ##################################################
# Evader Start Pos: 57, 48
# Length of Buffer: 23914
# Episode 395/400  Reward: 21.72  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 760  P2 Area Seen: 709  P3 Area Seen: 896
# ##################################################
# Evader Start Pos: 57, 48
# Episode 396 step count: 200, evader pos: 1, 1
# Episode 396 step count: 400, evader pos: 1, 1
# Length of Buffer: 23950
# Episode 396/400  Reward: 184.92  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 603  P2 Area Seen: 747  P3 Area Seen: 2650
# ##################################################
# Evader Start Pos: 61, 42
# Episode 397 step count: 200, evader pos: 1, 1
# Episode 397 step count: 400, evader pos: 1, 1
# Episode 397 step count: 600, evader pos: 1, 1
# Episode 397 step count: 800, evader pos: 1, 1
# Episode 397 step count: 1000, evader pos: 1, 1
# Episode 397 step count: 1200, evader pos: 1, 1
# Episode 397 step count: 1400, evader pos: 1, 1
# Episode 397 step count: 1600, evader pos: 1, 1
# Length of Buffer: 24008
# Episode 397/400  Reward: 165.42  Epsilon: 0.100   | Successful Pursuers: 2   Evader Speed: 1.0
# P1 Area Seen: 3544  P2 Area Seen: 841  P3 Area Seen: 3265
# ##################################################
# Evader Start Pos: 59, 12
# Length of Buffer: 24033
# Episode 398/400  Reward: 15.41  Epsilon: 0.100   | Successful Pursuers: 0   Evader Speed: 1.0
# P1 Area Seen: 760  P2 Area Seen: 508  P3 Area Seen: 822
# ##################################################
# Evader Start Pos: 50, 18
# Length of Buffer: 24070
# Episode 399/400  Reward: 48.98  Epsilon: 0.100   | Successful Pursuers: 1   Evader Speed: 1.0
# P1 Area Seen: 705  P2 Area Seen: 601  P3 Area Seen: 560
# ##################################################
# Evader Start Pos: 57, 48
# Episode 400 step count: 200, evader pos: 19, 1
# Episode 400 step count: 400, evader pos: 19, 1
# Episode 400 step count: 600, evader pos: 19, 1
# Episode 400 step count: 800, evader pos: 19, 1
# Length of Buffer: 24134
# Episode 400/400  Reward: 189.95  Epsilon: 0.100   | Successful Pursuers: 3   Evader Speed: 1.0
# P1 Area Seen: 2370  P2 Area Seen: 810  P3 Area Seen: 2840
# Training complete!
